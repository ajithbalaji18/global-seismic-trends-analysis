# %%
# !pip install sqlalchemy pymysql
import pandas as pd
from sqlalchemy import create_engine

df = pd.read_csv("earthquake_cleaned(4).csv")

# %%
engine = create_engine(
    "mysql+pymysql://root:YOUR_PASSWORD@localhost/seismic_db"
)

# %%
df.to_sql(
    name='earthquakes',
    con=engine,
    if_exists='replace',
    index=False
)

# %%
SELECT * FROM earthquakes LIMIT 10;

# %%
df.shape[0]

# %%
df.shape[0]
DESCRIBE earthquakes;
